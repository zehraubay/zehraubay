# %% [markdown]
# <a href="https://colab.research.google.com/github/zehraubay/zehraubay/blob/main/Yolov8x.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.9/41.9 kB 2.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 871.6/871.6 kB 20.3 MB/s eta 0:00:00
# ...

# %%
import ultralytics
import os
import torch
from pathlib import Path
from ultralytics import YOLO
from IPython.display import Image, display
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
model = YOLO('yolov8x.pt')
# Out:
# ...
# 100%|██████████| 131M/131M [00:00<00:00, 332MB/s]

# %%
model.train(data='/content/drive/MyDrive/SON/data.yaml', epochs=30, imgsz=640, batch=16, device=0, cache=True, cos_lr=True, amp=True)
# Out:
# Ultralytics YOLOv8.2.93 🚀 Python-3.10.12 torch-2.4.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
conf_matrix_path = '/content/runs/detect/train/confusion_matrix.png'
if os.path.exists(conf_matrix_path):
    display(Image(filename=conf_matrix_path, width=600))
else:
    print("Confusion matrix görüntüsü bulunamadı.")

results_graph_path = '/content/runs/detect/train/results.png'
if os.path.exists(results_graph_path):
    display(Image(filename=results_graph_path, width=600))
else:
    print("Sonuçlar grafiği bulunamadı.")
